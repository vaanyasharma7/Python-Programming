# %% [markdown]
# # Chapter 1 - Getting Started with Python

# %%
print("Python is a high-level programming language that is easy to learn and widely used in areas like web development, data analysis, artificial intelligence, automation, and scientific computing. Its simple syntax makes it beginner-friendly while still being powerful enough for professionals.")
# Out:
# Python is a high-level programming language that is easy to learn and widely used in areas like web development, data analysis, artificial intelligence, automation, and scientific computing. Its simple syntax makes it beginner-friendly while still being powerful enough for professionals.

# %% [markdown]
# # Introduction to Python

# %%
print("Python was created by Guido van Rossum and released in 1991. It focuses on readability and simplicity, which means you can write programs using fewer lines of code compared to many other languages. Python is open-source and runs on Windows, macOS, and Linux.")
# Out:
# Python was created by Guido van Rossum and released in 1991. It focuses on readability and simplicity, which means you can write programs using fewer lines of code compared to many other languages. Python is open-source and runs on Windows, macOS, and Linux.

# %% [markdown]
# ### Q/A

# %%
print("What is interactive programming in Python?")
# Out:
# What is interactive programming in Python?

# %%
print("Interactive programming means writing and executing Python code line by line and getting immediate output. It is mainly used for learning, testing small pieces of code, and debugging. The user interacts directly with the Python interpreter.")
# Out:
# Interactive programming means writing and executing Python code line by line and getting immediate output. It is mainly used for learning, testing small pieces of code, and debugging. The user interacts directly with the Python interpreter.

# %%
print("Advantages:")
print("Immediate results")
print("Easy to test logic")
print("Beginner-friendly")
# Out:
# Advantages:
# Immediate results
# Easy to test logic
# Beginner-friendly

# %%
print("What is script programming in Python?")
# Out:
# What is script programming in Python?

# %%
print("Script programming involves writing Python code in a file (usually with a .py extension) and executing the entire file at once. It is mainly used for developing complete programs and applications.")
# Out:
# Script programming involves writing Python code in a file (usually with a .py extension) and executing the entire file at once. It is mainly used for developing complete programs and applications.

# %%
print("Advantages:")
print("Suitable for large programs")
print("Code can be reused")
print("Easier to maintain")
# Out:
# Advantages:
# Suitable for large programs
# Code can be reused
# Easier to maintain

# %%
print("Interactive Python in Jupyter")
# Out:
# Interactive Python in Jupyter

# %%
print("In Jupyter Notebook, interactive programming is done by writing code in cells. Each cell can be executed independently, and the output is shown immediately below the cell. This makes Jupyter very useful for learning and experimentation.")
# Out:
# In Jupyter Notebook, interactive programming is done by writing code in cells. Each cell can be executed independently, and the output is shown immediately below the cell. This makes Jupyter very useful for learning and experimentation.

# %%
print("Script Mode in Jupyter Notebook")
# Out:
# Script Mode in Jupyter Notebook

# %%
print("Script mode in Jupyter refers to writing multiple cells that together form a complete program. The notebook can be run cell by cell or all at once, similar to executing a script.")
# Out:
# Script mode in Jupyter refers to writing multiple cells that together form a complete program. The notebook can be run cell by cell or all at once, similar to executing a script.

# %%
print("Dynamic Types in Python")
# Out:
# Dynamic Types in Python

# %%
print("Python uses dynamic typing, which means you do not need to declare the type of a variable explicitly. The type is decided automatically based on the value assigned to the variable.")
# Out:
# Python uses dynamic typing, which means you do not need to declare the type of a variable explicitly. The type is decided automatically based on the value assigned to the variable.

# %% [markdown]
# > **Example:**

# %%
print("x = 10 → integer")
print("x = 'Hello' → string")
# Out:
# x = 10 → integer
# x = 'Hello' → string

# %%
print("What is the command to check the data type?")
# Out:
# What is the command to check the data type?

# %%
print("The built-in function type() is used to check the data type of a variable.")
# Out:
# The built-in function type() is used to check the data type of a variable.

# %%
print("What are immutable data types?")
# Out:
# What are immutable data types?

# %%
print("Immutable data types are those whose values cannot be changed after creation. If you try to modify them, a new object is created instead.")
# Out:
# Immutable data types are those whose values cannot be changed after creation. If you try to modify them, a new object is created instead.

# %% [markdown]
# **Examples:**

# %%
print("int")
print("float")
print("string")
print("tuple")
# Out:
# int
# float
# string
# tuple

# %%
print("What is a tuple?")
# Out:
# What is a tuple?

# %%
print("A tuple is an ordered collection of elements enclosed in parentheses (). Tuples are immutable, meaning their values cannot be changed once created.")
# Out:
# A tuple is an ordered collection of elements enclosed in parentheses (). Tuples are immutable, meaning their values cannot be changed once created.

# %% [markdown]
# **Example**

# %%
print("my_tuple = (1, 2, 3)")
# Out:
# my_tuple = (1, 2, 3)

# %% [markdown]
# - - -

# %% [markdown]
# ## Variable – Native Python

# %% [markdown]
# - - -

# %%
print("Variables in Python are used to store data values. A variable name acts as a reference to the data stored in memory.")
# Out:
# Variables in Python are used to store data values. A variable name acts as a reference to the data stored in memory.

# %% [markdown]
# ## Variable Definition

# %%
print("A variable is a named location used to store data in memory. The value of a variable can be changed during program execution.")
# Out:
# A variable is a named location used to store data in memory. The value of a variable can be changed during program execution.

# %% [markdown]
# ## Naming and Using Variables

# %% [markdown]
# **Rules for naming variables:**

# %%
print("Must start with a letter or underscore")
print("Cannot start with a number")
print("No spaces allowed")
print("Should not be a Python keyword")
# Out:
# Must start with a letter or underscore
# Cannot start with a number
# No spaces allowed
# Should not be a Python keyword

# %% [markdown]
# **Note on Keywords**

# %%
print("Python has reserved words called keywords which have special meanings. These should not be used as variable names to avoid errors and confusion.")
# Out:
# Python has reserved words called keywords which have special meanings. These should not be used as variable names to avoid errors and confusion.

# %% [markdown]
# ## Variable Types

# %% [markdown]
# ---

# %% [markdown]
# **Common variable types in Python include:**

# %%
print("int (numbers)")
print("float (decimal numbers)")
print("str (text)")
print("bool (True or False)")
# Out:
# int (numbers)
# float (decimal numbers)
# str (text)
# bool (True or False)

# %% [markdown]
# # String

# %%
print("A string is a sequence of characters enclosed within single quotes or double quotes. Strings are used to store text data.")
# Out:
# A string is a sequence of characters enclosed within single quotes or double quotes. Strings are used to store text data.

# %% [markdown]
# **Example**

# %%
print("name = 'Python'")
# Out:
# name = 'Python'

# %% [markdown]
# # Python String Built-in Methods

# %%
print("Python provides many built-in methods to work with strings. These methods help in modifying, searching, and formatting string data.")
# Out:
# Python provides many built-in methods to work with strings. These methods help in modifying, searching, and formatting string data.

# %% [markdown]
# ## Case Conversion Methods

# %%
print("upper() converts all characters in a string to uppercase.")
# Out:
# upper() converts all characters in a string to uppercase.

# %%
print("lower() converts all characters in a string to lowercase.")
# Out:
# lower() converts all characters in a string to lowercase.

# %%
print("title() converts the first character of each word to uppercase.")
# Out:
# title() converts the first character of each word to uppercase.

# %%
print("capitalize() converts only the first character of the string to uppercase.")
# Out:
# capitalize() converts only the first character of the string to uppercase.

# %%
print("swapcase() swaps uppercase letters to lowercase and vice versa.")
# Out:
# swapcase() swaps uppercase letters to lowercase and vice versa.

# %% [markdown]
# ## Remove Spaces / Cleanup

# %%
print("strip() removes spaces from both the beginning and end of a string.")
# Out:
# strip() removes spaces from both the beginning and end of a string.

# %%
print("lstrip() removes spaces from the left side of a string.")
# Out:
# lstrip() removes spaces from the left side of a string.

# %%
print("rstrip() removes spaces from the right side of a string.")
# Out:
# rstrip() removes spaces from the right side of a string.

# %% [markdown]
# # Practise

# %%
a =  4576
r = a
while r > 0:
    print_value = r %10
    print(print_value)
    r = r//10
# Out:
# 6
# 7
# 5
# 4

# %%
n=int(input("Enter number:"))
temp=n
rev=0
while(n>0):
    dig=n%10
    rev=rev*10+dig
    n=n//10
if(temp==rev):
    print("The number is a palindrome!")
else:
    print("The number isn't a palindrome!")
# Out:
# Enter number: 56
# The number isn't a palindrome!

# %%
num = int(input("Enter a number: "))
n = num
power = len(str(num))
total = 0

while n > 0:
    digit = n % 10
    total += digit ** power
    n //= 10

if total == num:
    print("Armstrong Number")
else:
    print("Not an Armstrong Number")
# Out:
# Enter a number:  345
# Not an Armstrong Number
